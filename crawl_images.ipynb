# %%
import pandas as pd
data = pd.read_csv('film_cleaned.csv')

from google_images_download import google_images_download   #importing the library

response = google_images_download.googleimagesdownload()   #class instantiation

keywords = ""

for i in range(len(data)):
    name = data["Title"].iloc[i]
    
    name = name.replace(",", "").replace(":", "").replace("?", "").replace("/", " ")
      
    name = "film " + name + " (" + str(data["Year"].iloc[i]) + "),"
    
    keywords += name

print(keywords)

#arguments = {"keywords":keywords,"limit":1,"print_urls":True}   #creating list of arguments
#paths = response.download(arguments)   #passing the arguments to the function
#print(paths)   #printing absolute paths of the downloaded images
# Out:
# film Tie Me Up! Tie Me Down! (1990),film High Heels (1991),film The Dead Zone (1983),film Cuba (1979),film Days of Heaven (1978),film Octopussy (1983),film Target Eagle (1984),film The American Angels Baptism of Blood (1989),film Subway (1985),film Camille Claudel (1990),film Fanny and Alexander (1982),film Tragedy of a Ridiculous Man (1982),film A Man & a Woman (1966),film A Man & a Woman Twenty Years Later (1986),film Un Hombre y una Mujer (1966),film The Official Story (1985),film The Lindbergh Kidnapping Case (1976),film Blackmail (1929),film Donovan's Reef (1963),film Tucker The Man & His Dream (1988),film Scrooged (1988),film Raiders of the Lost Ark (1981),film The Running Man (1987),film Predator 2 (1991),film Colors (1988),film Zandalee (1990),film Miles from Home (1988),film Happy Birthday to Me (1980),film Final Notice (1989),film Quintet (1979),film The Devil's Eye (1960),film Wild Strawberries (1957),film The Seventh Seal (1956),film Germicide (1992),film Dreams (1955),fi
# ...

# %%
import os.path
count = 0
bis = 0

test = []
for i in range(len(data)):
    name = data["Title"].iloc[i]
    
    name = name.replace(",", "").replace(":", "").replace("?", "").replace("/", " ")
      
    name = "film " + name + " (" + str(data["Year"].iloc[i]) + ")"
    
    test.append(name)
    
    path = "./downloads/" + name
    
    if os.path.isdir(path):
        count += 1
    
    bis += 1

# function to get unique values 
def unique(list1): 
  
    # intilize a null list 
    unique_list = [] 
      
    # traverse for all elements 
    for x in list1: 
        # check if exists in unique_list or not 
        if x not in unique_list: 
            unique_list.append(x) 
        else:
            print(x)
    # print list 
    return unique_list
        
len(data)
# Out:
# 1656
